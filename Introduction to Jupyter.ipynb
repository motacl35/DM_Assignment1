# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Markdown cells allow me to write Markdown
# # Heading
# ## Heading 2
# ### Heading 3
#
# * bullet 1
# *  **bullet 2**
# *   *bullet 3*
#
# (Jupyter Homepage)(https://jupyter.org/)

# %% [markdown]
# ![Python](python.png)
